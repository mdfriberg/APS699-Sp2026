# %% [markdown]
# ## Data summary tables
# These tables summarize datasets used in the course and separate sources into raw observational data, model or reanalysis outputs, and value-added derived products. The separation highlights what is directly measured versus what is simulated and what is computed or curated from upstream sources.
#
# | Category | Dataset / Product Name | Type | Platform / Method | Temporal Coverage | Spatial Coverage / Domain | Purpose / Use | Access URL | Data Policy / Archive |
# |---------|------------------------|------|-------------------|-------------------|---------------------------|---------------|------------|-----------------------|
# | A | NOAA Tail Doppler Radar (TDR) | Observation | Aircraft Doppler radar | Campaign-specific | Hurricanes | Hurricane wind structure | https://www.aoml.noaa.gov/hrd/data_sub/ | NOAA Open Data |
# | A | IWRAP | Observation | Airborne radar profiler | Campaign-specific | Hurricanes | Wind & precipitation profiles | https://www.aoml.noaa.gov/hrd/technology/iwrap/ | NOAA Open Data |
# | A | ACTIVATE | Observation | Aircraft + satellite | 2019–2022 | Western North Atlantic | Aerosol–cloud–meteorology coupling | https://espo.nasa.gov/activate | NASA Open Data |
# | A | NASA AERONET | Observation | Sun photometer network | 2017–present | Global | Aerosol optical depth & size distribution | https://aeronet.gsfc.nasa.gov | NASA Open Data |
# | A | NASA PANDORA | Observation | Ground-based UV–VIS spectrometer | Site-dependent (minute resolution) | Global (PGN sites) | NO₂, O₃ column retrievals; satellite validation | https://pandora.gsfc.nasa.gov | NASA Open Data (SPD-41a) |
# | A | WFIP-3 | Observation | Multi-instrument field campaign | 2024–present | Coastal New England | Offshore wind processes | https://psl.noaa.gov/wfip3/ | NOAA / DOE |
# | A | DOE WindSentinel Buoy | Observation | Doppler lidar buoy | 2014–2016 | Offshore Virginia | Offshore wind climatology | https://a2e.energy.gov/projects/windsentinel | DOE Open Data |
# | B | WRF | Model | Mesoscale numerical weather model | Case-based | Regional | Weather simulation & sensitivity studies | https://www2.mmm.ucar.edu/wrf/users/ | NCAR / NSF |
# | B | HRRR v4 | Model | Operational NWP (3 km) | 2023–2025 | CONUS | High-resolution wind forecasting | https://rapidrefresh.noaa.gov/hrrr/ | NOAA Open Data |
# | B | RAP v5 | Model | Mesoscale NWP (13 km) | Ongoing | CONUS | Boundary conditions & regional analysis | https://rapidrefresh.noaa.gov/rap/ | NOAA Open Data |
# | B | Fast-JX | Model | Photolysis radiative transfer model | Case-based | Vertical columns | Photolysis sensitivity analysis | https://github.com/NCAR/Fast-JX | Open Source |
# | C | LLJ Event Catalogs | Derived | Threshold-based detection | 2023–2025 | WFIP-3 sites | Low-level jet climatology | https://psl.noaa.gov/data/composites/ | NOAA FAIR |
# | C | Temperature Advection Fields | Derived | Line-integral method | 2023–2025 | WFIP-3 sites | Warm/cold air advection diagnosis | https://rapidrefresh.noaa.gov/hrrr/ | NOAA Open Data |
# | C | Hub-height Wind Statistics | Derived | Directional & temporal statistics | 2015 | Offshore Virginia | Offshore wind energy assessment | https://a2e.energy.gov/projects/windsentinel | DOE Public Access |
# | C | 3-D Ice Shell Simulations | Derived | Thermo-mechanical modeling | Parameter sweeps | Europa, Ganymede | Ocean-world interior processes | https://zenodo.org | NSF / NASA Open Science |

# %% [markdown]
# ### Homework 1 requests
# 1. Correct information for your assigned dataset in the table.
# 2. Find where to access the data (agency data site, AWS, etc.).
# 3. Find and add the product/algorithm theoretical document link for your dataset.
# 4. Find 1-3 reputable python libraries that facilitate data access.
